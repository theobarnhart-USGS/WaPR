# %%
from netCDF4 import Dataset

# %%
ds = Dataset('../UOG/data/haines_tiffs/test.nc','r')

# %%
ds.variables
# Out:
# OrderedDict([('lambert_conformal_conic', <class 'netCDF4._netCDF4.Variable'>
#               |S1 lambert_conformal_conic()
#                   grid_mapping_name: lambert_conformal_conic
#                   longitude_of_central_meridian: -104.0
#                   false_easting: 0.0
#                   false_northing: 0.0
#                   latitude_of_projection_origin: 0.0
#                   standard_parallel: [ 33.  45.]
#                   longitude_of_prime_meridian: 0.0
#                   semi_major_axis: 6378137.0
#                   inverse_flattening: 298.257222101
# ...

# %%
rast = ds.variables['Band37']

# %%
rast.shape
# Out:
# (448, 466)

# %%
plt.figure(figsize=(10,10))
plt.pcolormesh(rast)
plt.axis('equal')
plt.colorbar()
